# %%
# SQL Alchemy
from sqlalchemy import create_engine, text

# Pandas
import pandas as pd

# Matplotlib
import matplotlib.pyplot as plt

# NumPy
import numpy as np

# %%
# Create Engine and Pass in Postgres Connection
# Setup to Connect to Database 
connection_string = ("postgresql+psycopg2://postgres:1234@localhost:5433/Employee_database")
engine = create_engine(connection_string)                     
conn = engine.connect()

# %%
# Query All Records in the Salaries Table
salaries_data = pd.read_sql("SELECT * FROM salaries", conn)
salaries_data.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
# Display a statistical overview:
salaries_data['salary'].describe()
# Out:
# count    300024.000000
# mean      52970.732451
# std       14301.478491
# min       40000.000000
# 25%       40000.000000
# 50%       48681.000000
# 75%       61758.000000
# max      129492.000000
# Name: salary, dtype: float64

# %%
plt.rcParams['figure.figsize']=(10,7)
plt.hist(salaries_data['salary'],bins=9,color='xkcd:blue',alpha=1,edgecolor='black')
plt.title('Pewlett Hackard Employee\nSalary Ranges',fontsize=20,pad=40)
plt.xlabel('Salaries ($)',fontsize=16,color='black',labelpad=20)
plt.ylabel('Frequency Count',fontsize=16,color='black',labelpad=20)
plt.xlim(36000,130000)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
